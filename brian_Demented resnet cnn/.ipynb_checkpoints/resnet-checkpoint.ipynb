# %%
import keras 
from keras import layers
import tensorflow as tf
import cv2
import matplotlib.pyplot as plt
from keras.callbacks import EarlyStopping,ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
import os
from keras.utils import plot_model
from tqdm.keras import TqdmCallback

# %%
os.listdir("seg_train")
# Out:
# ['buildings', 'forest', 'glacier', 'mountain', 'sea', 'street']

# %%
im='seg_train/glacier/10.jpg'
plt.figure(figsize=(12,12))
plt.subplot(1,2,1)
plt.imshow(cv2.imread(im))
plt.title("glacier")
s='seg_test/street/20088.jpg'
plt.subplot(1 , 2, 2)     # means the fig has 1 row and 2 columns and this plot is the secnd plot 
plt.imshow(cv2.imread(s))
plt.title('Street')
plt.show()

# %%
trian_gene=ImageDataGenerator(rescale=1/255,rotation_range=15,width_shift_range=0.1,height_shift_range=0.1,zoom_range=0.1,shear_range=0.1,horizontal_flip=True,fill_mode="nearest")

# %%
trian_data=trian_gene.flow_from_directory(directory="seg_train",target_size=(150,150),batch_size=32,shuffle=True,class_mode='categorical')
# Out:
# Found 14034 images belonging to 6 classes.

# %%
test_gen=ImageDataGenerator(rescale=1./255)
test_data=test_gen.flow_from_directory('seg_test',target_size=(150,150),batch_size=1,shuffle=True)
# Out:
# Found 3000 images belonging to 6 classes.

# %%
trian_data.class_indices
# Out:
# {'buildings': 0,
#  'forest': 1,
#  'glacier': 2,
#  'mountain': 3,
#  'sea': 4,
#  'street': 5}

# %%
early_stopping_monitor = EarlyStopping(monitor='val_accuracy', patience=5, restore_best_weights=True)

reduce_lr_on_plateau = keras.callbacks.ReduceLROnPlateau(
    monitor='val_accuracy',
    patience=3,
)

# %%
def make_model(input_shape, num_classes):
    inputs=keras.Input(shape=input_shape)
    x=inputs
    x=keras.layers.Conv2D(32,3,strides=2,padding='same')(x)
    x=keras.layers.BatchNormalization()(x)
    x=keras.layers.Activation('relu')(x)
    
    x=keras.layers.Conv2D(64,3,strides=2,padding='same')(x)
    x=keras.layers.BatchNormalization()(x)
    x=keras.layers.Activation("relu")(x)
    skip_shortcut=x
    for size in [128, 256, 512, 728]:
        x = layers.Activation("relu")(x)
        x = layers.SeparableConv2D(size, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.Activation("relu")(x)
        x = layers.SeparableConv2D(size, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)
        
        x=keras.layers.MaxPooling2D(3,strides=2,padding='same')(x)
        
        residual=keras.layers.Conv2D(size,1,strides=2,padding='same')(skip_shortcut)
        x=layers.add([x,residual])
        skip_shortcut=x
        
    x=layers.Activation("relu")(x)
    x = layers.SeparableConv2D(1024, 3, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x) 
    x=layers.Flatten()(x)
    
    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(6, activation="softmax")(x)
    return keras.Model(inputs, outputs)

model = make_model(input_shape=(150,150,3), num_classes=6)
keras.utils.plot_model(model, show_shapes=True,show_layer_names=True)

# %%
inputs=keras.layers.Input(shape=(150,150,3))
x=inputs
x=layers.Conv2D(32,3,strides=2,activation="relu",padding="valid")(x)
x=keras.layers.Conv2D(filters=32,kernel_size=(3,3),activation="relu",padding="same")(x)  
x=keras.layers.MaxPooling2D(pool_size=(2,2))(x)
x=keras.layers.BatchNormalization()(x)
skip_short=x
for i in [64,128,265,512]:
    x=keras.layers.Activation("relu")(x)
    x=keras.layers.Conv2D(filters=i,kernel_size=(3,3),activation="relu",padding="same")(x) 
    
    
    x=layers.Conv2D(i,3,activation="relu",padding="valid")(x)
    x=keras.layers.Conv2D(filters=32,kernel_size=(3,3),activation="relu",padding="same")(x)  
    x=keras.layers.MaxPooling2D(pool_size=(2,2))(x)
    x=keras.layers.BatchNormalization()(x)


    x=layers.Conv2D(i,3,strides=2,activation="relu",padding="valid")(x)
    x=keras.layers.Conv2D(filters=32,kernel_size=(3,3),activation="relu",padding="same")(x)  
    x=keras.layers.MaxPooling2D(pool_size=(2,2))(x)
    x=keras.layers.BatchNormalization()(x)



    x=layers.Conv2D(i,3,activation="relu",padding="valid")(x)
    x=keras.layers.Conv2D(filters=32,kernel_size=(3,3),activation="relu",padding="same")(x)  
    x=keras.layers.MaxPooling2D(pool_size=(2,2))(x)
    x=keras.layers.BatchNormalization()(x)

    x=keras.layers.Conv2D(filters=i,kernel_size=(3,3),padding="same")(x)
    res=keras.layers.Conv2D(filters=i,kernel_size=(3,3),padding="same")(skip_short)
    x=keras.layers.add([x,res])
    skip_short=x
    
    
x=keras.layers.Activation("relu")(x)    
x=keras.layers.Conv2D(filters=32,kernel_size=(3,3),activation="relu",padding="same")(x)  
x=keras.layers.MaxPooling2D(pool_size=(2,2))(x)
x=keras.layers.BatchNormalization()(x)

x=keras.layers.Conv2D(filters=32,kernel_size=(3,3),activation="relu",padding="same")(x)  
x=keras.layers.MaxPooling2D(pool_size=(2,2))(x)
x=keras.layers.BatchNormalization()(x)

x=keras.layers.Flatten()(x)
x=keras.layers.Dense(1000,activation="relu")(x)

x=keras.layers.Dense(500,activation="relu")(x)
x=keras.layers.Dense(6,activation="softmax")(x)

# %%
model=keras.Model(inputs=inputs,outputs=x)

# %%
model.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_11 (InputLayer)          [(None, 150, 150, 3  0           []
#                                 )]
#
#  conv2d_202 (Conv2D)            (None, 74, 74, 32)   896         ['input_11[0][0]']
#
#  conv2d_203 (Conv2D)            (None, 74, 74, 32)   9248        ['conv2d_202[0][0]']
#
#  max_pooling2d_72 (MaxPooling2D  (None, 37, 37, 32)  0           ['conv2d_203[0][0]']
#  )
#
#  batch_normalization_79 (BatchN  (None, 37, 37, 32)  128         ['max_pooling2d_72[0][0]']
#  ormalization)
#
#  activation_39 (Activation)     (None, 37, 37, 32)   0           ['batch_normalization_79[0][0]']
#
#  conv2d_204 (Conv2D)            (None, 37, 37, 64)   18496       ['activation_39[0][0]']
#
#  conv2d_205 (Conv2D)            (None, 35, 35, 64)   36928       ['conv2d_204[0][0]']
#
#  conv2d_206 (Conv2D)            (None, 35, 35, 32)   18464       ['conv2d_205[0][0]']
#
#  max_pooling2d_73 (MaxPooling2D  (None, 17, 17, 32)  0           ['conv2d_206[0][0]']
#  )
#
#  batch_normalization_80 (BatchN  (None, 17, 17, 32)  128         ['max_pooling2d_73[0][0]']
#  ormalization)
#
#  conv2d_207 (Conv2D)            (None, 8, 8, 64)     18496       ['batch_normalization_80[0][0]']
#
#  conv2d_208 (Conv2D)            (None, 8, 8, 32)     18464       ['conv2d_207[0][0]']
#
#  max_pooling2d_74 (MaxPooling2D  (None, 4, 4, 32)    0           ['conv2d_208[0][0]']
#  )
#
#  batch_normalization_81 (BatchN  (None, 4, 4, 32)    128         ['max_pooling2d_74[0][0]']
#  ormalization)
#
#  conv2d_209 (Conv2D)            (None, 2, 2, 64)     18496       ['batch_normalization_81[0][0]']
#
#  conv2d_210 (Conv2D)            (None, 2, 2, 32)     18464       ['conv2d_209[0][0]']
#
#  max_pooling2d_75 (MaxPooling2D  (None, 1, 1, 32)    0           ['conv2d_210[0][0]']
#  )
#
#  batch_normalization_82 (BatchN  (None, 1, 1, 32)    128         ['max_pooling2d_75[0][0]']
#  ormalization)
#
#  conv2d_211 (Conv2D)            (None, 1, 1, 64)     18496       ['batch_normalization_82[0][0]']
#
#  conv2d_212 (Conv2D)            (None, 37, 37, 64)   18496       ['batch_normalization_79[0][0]']
#
#  add_24 (Add)                   (None, 37, 37, 64)   0           ['conv2d_211[0][0]',
#                                                                   'conv2d_212[0][0]']
#
#  activation_40 (Activation)     (None, 37, 37, 64)   0           ['add_24[0][0]']
#
#  conv2d_213 (Conv2D)            (None, 37, 37, 128)  73856       ['activation_40[0][0]']
#
#  conv2d_214 (Conv2D)            (None, 35, 35, 128)  147584      ['conv2d_213[0][0]']
#
#  conv2d_215 (Conv2D)            (None, 35, 35, 32)   36896       ['conv2d_214[0][0]']
#
#  max_pooling2d_76 (MaxPooling2D  (None, 17, 17, 32)  0           ['conv2d_215[0][0]']
#  )
#
#  batch_normalization_83 (BatchN  (None, 17, 17, 32)  128         ['max_pooling2d_76[0][0]']
#  ormalization)
#
#  conv2d_216 (Conv2D)            (None, 8, 8, 128)    36992       ['batch_normalization_83[0][0]']
#
#  conv2d_217 (Conv2D)            (None, 8, 8, 32)     36896       ['conv2d_216[0][0]']
#
#  max_pooling2d_77 (MaxPooling2D  (None, 4, 4, 32)    0           ['conv2d_217[0][0]']
#  )
#
#  batch_normalization_84 (BatchN  (None, 4, 4, 32)    128         ['max_pooling2d_77[0][0]']
#  ormalization)
#
#  conv2d_218 (Conv2D)            (None, 2, 2, 128)    36992       ['batch_normalization_84[0][0]']
#  conv2d_219 (Conv2D)            (None, 2, 2, 32)     36896       ['conv2d_218[0][0]']
#
#  max_pooling2d_78 (MaxPooling2D  (None, 1, 1, 32)    0           ['conv2d_219[0][0]']
#  )
#
#  batch_normalization_85 (BatchN  (None, 1, 1, 32)    128         ['max_pooling2d_78[0][0]']
#  ormalization)
#
#  conv2d_220 (Conv2D)            (None, 1, 1, 128)    36992       ['batch_normalization_85[0][0]']
#
#  conv2d_221 (Conv2D)            (None, 37, 37, 128)  73856       ['add_24[0][0]']
#
#  add_25 (Add)                   (None, 37, 37, 128)  0           ['conv2d_220[0][0]',
#                                                                   'conv2d_221[0][0]']
#
#  activation_41 (Activation)     (None, 37, 37, 128)  0           ['add_25[0][0]']
#
#  conv2d_222 (Conv2D)            (None, 37, 37, 265)  305545      ['activation_41[0][0]']
#
#  conv2d_223 (Conv2D)            (None, 35, 35, 265)  632290      ['conv2d_222[0][0]']
#
#  conv2d_224 (Conv2D)            (None, 35, 35, 32)   76352       ['conv2d_223[0][0]']
#
#  max_pooling2d_79 (MaxPooling2D  (None, 17, 17, 32)  0           ['conv2d_224[0][0]']
#  )
#
#  batch_normalization_86 (BatchN  (None, 17, 17, 32)  128         ['max_pooling2d_79[0][0]']
#  ormalization)
#
#  conv2d_225 (Conv2D)            (None, 8, 8, 265)    76585       ['batch_normalization_86[0][0]']
#
#  conv2d_226 (Conv2D)            (None, 8, 8, 32)     76352       ['conv2d_225[0][0]']
#
#  max_pooling2d_80 (MaxPooling2D  (None, 4, 4, 32)    0           ['conv2d_226[0][0]']
#  )
#
#  batch_normalization_87 (BatchN  (None, 4, 4, 32)    128         ['max_pooling2d_80[0][0]']
#  ormalization)
#
#  conv2d_227 (Conv2D)            (None, 2, 2, 265)    76585       ['batch_normalization_87[0][0]']
#
#  conv2d_228 (Conv2D)            (None, 2, 2, 32)     76352       ['conv2d_227[0][0]']
#
#  max_pooling2d_81 (MaxPooling2D  (None, 1, 1, 32)    0           ['conv2d_228[0][0]']
#  )
#
#  batch_normalization_88 (BatchN  (None, 1, 1, 32)    128         ['max_pooling2d_81[0][0]']
#  ormalization)
#
#  conv2d_229 (Conv2D)            (None, 1, 1, 265)    76585       ['batch_normalization_88[0][0]']
#
#  conv2d_230 (Conv2D)            (None, 37, 37, 265)  305545      ['add_25[0][0]']
#
#  add_26 (Add)                   (None, 37, 37, 265)  0           ['conv2d_229[0][0]',
#                                                                   'conv2d_230[0][0]']
#
#  activation_42 (Activation)     (None, 37, 37, 265)  0           ['add_26[0][0]']
#
#  conv2d_231 (Conv2D)            (None, 37, 37, 512)  1221632     ['activation_42[0][0]']
#
#  conv2d_232 (Conv2D)            (None, 35, 35, 512)  2359808     ['conv2d_231[0][0]']
#
#  conv2d_233 (Conv2D)            (None, 35, 35, 32)   147488      ['conv2d_232[0][0]']
#
#  max_pooling2d_82 (MaxPooling2D  (None, 17, 17, 32)  0           ['conv2d_233[0][0]']
#  )
#
#  batch_normalization_89 (BatchN  (None, 17, 17, 32)  128         ['max_pooling2d_82[0][0]']
#  ormalization)
#
#  conv2d_234 (Conv2D)            (None, 8, 8, 512)    147968      ['batch_normalization_89[0][0]']
#
#  conv2d_235 (Conv2D)            (None, 8, 8, 32)     147488      ['conv2d_234[0][0]']
#
#  max_pooling2d_83 (MaxPooling2D  (None, 4, 4, 32)    0           ['conv2d_235[0][0]']
#  )
#
#  batch_normalization_90 (BatchN  (None, 4, 4, 32)    128         ['max_pooling2d_83[0][0]']
#  ormalization)
#
#  conv2d_236 (Conv2D)            (None, 2, 2, 512)    147968      ['batch_normalization_90[0][0]']
#
#  conv2d_237 (Conv2D)            (None, 2, 2, 32)     147488      ['conv2d_236[0][0]']
#
#  max_pooling2d_84 (MaxPooling2D  (None, 1, 1, 32)    0           ['conv2d_237[0][0]']
#  )
#
#  batch_normalization_91 (BatchN  (None, 1, 1, 32)    128         ['max_pooling2d_84[0][0]']
#  ormalization)
#
#  conv2d_238 (Conv2D)            (None, 1, 1, 512)    147968      ['batch_normalization_91[0][0]']
#
#  conv2d_239 (Conv2D)            (None, 37, 37, 512)  1221632     ['add_26[0][0]']
#
#  add_27 (Add)                   (None, 37, 37, 512)  0           ['conv2d_238[0][0]',
#                                                                   'conv2d_239[0][0]']
#
#  activation_43 (Activation)     (None, 37, 37, 512)  0           ['add_27[0][0]']
#
#  conv2d_240 (Conv2D)            (None, 37, 37, 32)   147488      ['activation_43[0][0]']
#
#  max_pooling2d_85 (MaxPooling2D  (None, 18, 18, 32)  0           ['conv2d_240[0][0]']
#  )
#
#  batch_normalization_92 (BatchN  (None, 18, 18, 32)  128         ['max_pooling2d_85[0][0]']
#  ormalization)
#
#  conv2d_241 (Conv2D)            (None, 18, 18, 32)   9248        ['batch_normalization_92[0][0]']
#
#  max_pooling2d_86 (MaxPooling2D  (None, 9, 9, 32)    0           ['conv2d_241[0][0]']
#  )
#
#  batch_normalization_93 (BatchN  (None, 9, 9, 32)    128         ['max_pooling2d_86[0][0]']
#  ormalization)
#
#  flatten_4 (Flatten)            (None, 2592)         0           ['batch_normalization_93[0][0]']
#
#  dense_4 (Dense)                (None, 1000)         2593000     ['flatten_4[0][0]']
#
#  dense_5 (Dense)                (None, 500)          500500      ['dense_4[0][0]']
#
#  dense_6 (Dense)                (None, 6)            3006        ['dense_5[0][0]']
#
# ==================================================================================================
# Total params: 11,358,697
# Trainable params: 11,357,737
# Non-trainable params: 960
# __________________________________________________________________________________________________

# %%
keras.utils.plot_model(model, show_shapes=True,show_layer_names=True)

# %%
model.compile(optimizer="adam",loss="categorical_crossentropy",metrics=["accuracy"])

# %%
h=model.fit(trian_data,validation_data=test_data,epochs=20,batch_size=32,callbacks=[TqdmCallback(verbose=1),reduce_lr_on_plateau, early_stopping_monitor])
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Epoch 1/20
# 439/439 [==============================] - 358s 591ms/step - loss: 1.0556 - accuracy: 0.6127 - val_loss: 0.9722 - val_accuracy: 0.6313 - lr: 0.0010
# Epoch 2/20
# 439/439 [==============================] - 251s 571ms/step - loss: 0.7974 - accuracy: 0.7008 - val_loss: 1.1920 - val_accuracy: 0.6257 - lr: 0.0010
# Epoch 3/20
# 439/439 [==============================] - 253s 576ms/step - loss: 0.6879 - accuracy: 0.7450 - val_loss: 0.9763 - val_accuracy: 0.6513 - lr: 0.0010
# Epoch 4/20
# 439/439 [==============================] - 254s 578ms/step - loss: 0.6074 - accuracy: 0.7780 - val_loss: 1.6407 - val_accuracy: 0.5453 - lr: 0.0010
# Epoch 5/20
# 439/439 [==============================] - 254s 578ms/step - loss: 0.5545 - accuracy: 0.8011 - val_loss: 0.7040 - val_accuracy: 0.7760 - lr: 0.0010
# Epoch 6/20
# 439/439 [==============================] - 256s 583ms/step - loss: 0.5186 - accuracy: 0.8162 - val_loss: 0.8488 - val_accuracy: 0.6887 - lr: 0.0010
# Epoch 7/20
# 439/439 [==============================] - 255s 581ms/step - loss: 0.4986 - accuracy: 0.8239 - val_loss: 0.9315 - val_accuracy: 0.7050 - lr: 0.0010
# Epoch 8/20
# 439/439 [==============================] - 255s 580ms/step - loss: 0.4881 - accuracy: 0.8226 - val_loss: 0.8090 - val_accuracy: 0.7087 - lr: 0.0010
# Epoch 9/20
# 439/439 [==============================] - 256s 582ms/step - loss: 0.3799 - accuracy: 0.8611 - val_loss: 0.4080 - val_accuracy: 0.8603 - lr: 1.0000e-04
# Epoch 10/20
# 439/439 [==============================] - 256s 584ms/step - loss: 0.3620 - accuracy: 0.8673 - val_loss: 0.3964 - val_accuracy: 0.8617 - lr: 1.0000e-04
# Epoch 11/20
# 439/439 [==============================] - 262s 596ms/step - loss: 0.3471 - accuracy: 0.8743 - val_loss: 0.3940 - val_accuracy: 0.8637 - lr: 1.0000e-04
# Epoch 12/20
# 439/439 [==============================] - 259s 590ms/step - loss: 0.3383 - accuracy: 0.8776 - val_loss: 0.3896 - val_accuracy: 0.8650 - lr: 1.0000e-04
# Epoch 13/20
# 439/439 [==============================] - 258s 588ms/step - loss: 0.3221 - accuracy: 0.8833 - val_loss: 0.3951 - val_accuracy: 0.8670 - lr: 1.0000e-04
# Epoch 14/20
# 439/439 [==============================] - 258s 587ms/step - loss: 0.3192 - accuracy: 0.8832 - val_loss: 0.3763 - val_accuracy: 0.8663 - lr: 1.0000e-04
# Epoch 15/20
# 439/439 [==============================] - 257s 585ms/step - loss: 0.3128 - accuracy: 0.8847 - val_loss: 0.4006 - val_accuracy: 0.8637 - lr: 1.0000e-04
# Epoch 16/20
# 439/439 [==============================] - 257s 585ms/step - loss: 0.3070 - accuracy: 0.8881 - val_loss: 0.3940 - val_accuracy: 0.8640 - lr: 1.0000e-04
# Epoch 17/20
# 439/439 [==============================] - 257s 584ms/step - loss: 0.2913 - accuracy: 0.8924 - val_loss: 0.3691 - val_accuracy: 0.8757 - lr: 1.0000e-05
# Epoch 18/20
# 439/439 [==============================] - 258s 587ms/step - loss: 0.2827 - accuracy: 0.8969 - val_loss: 0.3653 - val_accuracy: 0.8787 - lr: 1.0000e-05
# Epoch 19/20
# 439/439 [==============================] - 257s 585ms/step - loss: 0.2831 - accuracy: 0.8981 - val_loss: 0.3655 - val_accuracy: 0.8787 - lr: 1.0000e-05
# Epoch 20/20
# 439/439 [==============================] - 257s 584ms/step - loss: 0.2818 - accuracy: 0.8982 - val_loss: 0.3648 - val_accuracy: 0.8790 - lr: 1.0000e-05

# %%
model.evaluate(test_data)
# Out:
# 3000/3000 [==============================] - 55s 18ms/step - loss: 0.3648 - accuracy: 0.8790
# [0.36476656794548035, 0.8790000081062317]

# %%
h.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy', 'lr'])

# %%
import keras
from matplotlib import pyplot as plt
plt.plot(h.history['accuracy'])
plt.plot(h.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
import keras
from matplotlib import pyplot as plt
plt.plot(h.history['loss'])
plt.plot(h.history['val_loss'])
plt.title('model lose')
plt.ylabel('lose')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
import glob, random
images =glob.glob('seg_train/glacier/*.jpg')
for i in range (10):
    random_image = random.choice(images)
    print(random_image)
# Out:
# seg_train/glacier\1510.jpg
# seg_train/glacier\12173.jpg
# seg_train/glacier\9163.jpg
# seg_train/glacier\14167.jpg
# seg_train/glacier\8606.jpg
# seg_train/glacier\3175.jpg
# seg_train/glacier\4039.jpg
# seg_train/glacier\17708.jpg
# seg_train/glacier\8120.jpg
# seg_train/glacier\10291.jpg
